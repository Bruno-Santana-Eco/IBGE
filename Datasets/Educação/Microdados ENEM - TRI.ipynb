# %%
import pandas as pd
import os

# %%
os.chdir("D:\Trabalho\Microdados\DADOS")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Repositório GIT\Projetos\IBGE\Datasets\Educação\Microdados ENEM - TRI.ipynb Célula 2 line <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/Reposit%C3%B3rio%20GIT/Projetos/IBGE/Datasets/Educa%C3%A7%C3%A3o/Microdados%20ENEM%20-%20TRI.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> os.chdir("D:\Trabalho\Microdados\DADOS")
# ----> <a href='vscode-notebook-cell:/d%3A/Reposit%C3%B3rio%20GIT/Projetos/IBGE/Datasets/Educa%C3%A7%C3%A3o/Microdados%20ENEM%20-%20TRI.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> pwd
#
# NameError: name 'pwd' is not defined

# %%
pwd
# Out:
# 'D:\\Trabalho\\Microdados\\DADOS'

# %% [markdown]
# #### Para saber quual nome dos sheets

# %%
# Substitua 'seu_arquivo.xlsx' pelo nome do seu arquivo Excel
nome_do_arquivo = 'MICRODADOS_ENEM_2022.xlsx'

# Carregar as informações do arquivo Excel
excel_info = pd.ExcelFile(nome_do_arquivo)

# Obter nomes das planilhas disponíveis
nomes_das_planilhas = excel_info.sheet_names

# Imprimir os nomes das planilhas
print("Planilhas disponíveis:", nomes_das_planilhas)

# %% [markdown]
# #### Importar arquivo .csv

# %%
df=pd.read_csv('MICRODADOS_ENEM_2022.csv', sep=';', encoding='latin-1')

# %%
pd.set_option('display.max_columns', None)  # Configura para exibir todas as colunas
df.head(5)
# Out:
#    NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0  210057943671    2022               14       M                2
# 1  210057516120    2022               14       M                2
# 2  210057280536    2022                5       F                1
# 3  210055724397    2022                6       M                1
# 4  210055097896    2022                4       M                0
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  \
# 0            2                 1                1                2          1
# 1            1                 1                1               16          1
# 2            2                 1                1                2          1
# 3            3                 1                1                2          1
# 4            3                 1                1                1          1
#
#    TP_ENSINO  IN_TREINEIRO  CO_MUNICIPIO_ESC NO_MUNICIPIO_ESC  CO_UF_ESC  \
# ...

# %%
pd.set_option('display.max_columns', 10)

# %%
df1 = df.copy

# %%
df1 = df.head(1000)

# %%
df1.tail()
# Out:
#      NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 995  210055642015    2022                6       M                1
# 996  210055591467    2022                3       M                1
# 997  210057387803    2022                2       M                1
# 998  210057257170    2022                8       F                1
# 999  210054718093    2022                3       M                1
#
#      TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# 995            3                 1                1                4
# 996            2                 1                1                1
# 997            1                 1                2                0
# 998            2                 1                1                5
# 999            1                 1                1                1
#
#      TP_ESCOLA  TP_ENSINO  IN_TREINEIRO  CO_MUNICIPIO_ESC NO_MUNICIPIO_ESC  \
# ...

# %%
os.chdir("D:\Trabalho\Microdados\DADOS")

# %%
df1.to_excel('D:\Repositório GIT\Projetos\IBGE\Datasets\Educação\Microdado_Teste.xlsx', index=False)
